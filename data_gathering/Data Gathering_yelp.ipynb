# %%
import requests
yelp = open('./yelp.txt').read().split('\n')[3]
import pandas as pd

# %%
#DEfine API key and endpoint.  Then define header
api_key = yelp
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'bearer %s' % api_key}
parameters = {'limit': 50, 'offset':50, 'location': 'Seattle'}
response = requests.get(url = endpoint, params = parameters, headers = headers)

L = []
total = 1000
for i in range(total // 50):
    parameters = {'limit' : 50, 'offset' : 50 * i, 'location' : 'Seattle'}
    R = requests.get(url = endpoint, params = parameters, headers = headers).json()['businesses']
    L = L + R

# %%
#convert json string to dictionary
business_data = response.json()
print(business_data.keys())
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
business_data['businesses']
# Out:
# [{'id': '7F473Qfy0eRD6_5lgfWTSA',
#   'alias': 'taste-of-india-seattle',
#   'name': 'Taste of India',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HW44UOamjSJ86E2gd0XzTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taste-of-india-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1530,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.669083, 'longitude': -122.317484},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5517 Roosevelt Way NE',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98105',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['5517 Roosevelt Way NE', 'Seattle, WA 98105']},
#   'phone': '+12065281575',
#   'display_phone': '(206) 528-1575',
#   'distance': 5039.494501568876},
#  {'id': 'FrHhYevaOhs40xpuOpQiHg',
#   'alias': 'canlis-seattle',
#   'name': 'Canlis',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ckDxHbNcjdkR4Kr1kIE-vg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/canlis-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1456,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6430119, 'longitude': -122.3467676},
#   'transactions': ['pickup'],
#   'price': '$$$$',
#   'location': {'address1': '2576 Aurora Ave N',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98109',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2576 Aurora Ave N', 'Seattle, WA 98109']},
#   'phone': '+12062833313',
#   'display_phone': '(206) 283-3313',
#   'distance': 2130.343205095282},
#  {'id': 'a9iLwBAri52khGIR_rrUkw',
#   'alias': 'dahlia-bakery-seattle',
#   'name': 'Dahlia Bakery',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3w1ntQo9OUE8IwfLIheg_w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dahlia-bakery-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 996,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6131855205192,
#    'longitude': -122.340556830168},
#   'transactions': ['pickup'],
#   'price': '$',
#   'location': {'address1': '2001 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2001 4th Ave', 'Seattle, WA 98121']},
#   'phone': '+12064414540',
#   'display_phone': '(206) 441-4540',
#   'distance': 1411.9134769881557},
#  {'id': 'seXhmf0ry1gFsmLUDues5w',
#   'alias': 'honeyhole-sandwiches-seattle-2',
#   'name': 'HoneyHole Sandwiches',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gHbZaDZtB4UWawVP0b89Qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/honeyhole-sandwiches-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1383,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61393, 'longitude': -122.3232},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '703 E Pike St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['703 E Pike St', 'Seattle, WA 98122']},
#   'phone': '+12067091399',
#   'display_phone': '(206) 709-1399',
#   'distance': 1579.7786563851796},
#  {'id': '1EFQ8ePAtsgqWc3VyneBMw',
#   'alias': 'daily-dozen-doughnut-seattle',
#   'name': 'Daily Dozen Doughnut',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h8OKoRFyC14IvZR8pO1exA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/daily-dozen-doughnut-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1002,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'donuts', 'title': 'Donuts'},
#    {'alias': 'foodstands', 'title': 'Food Stands'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6086751, 'longitude': -122.3402434},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '93 Pike St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['93 Pike St', 'Seattle, WA 98101']},
#   'phone': '+12064677769',
#   'display_phone': '(206) 467-7769',
#   'distance': 1898.6275827863913},
#  {'id': '9OXEAAPONxcA2PQO75fnJQ',
#   'alias': 'the-walrus-and-the-carpenter-seattle',
#   'name': 'The Walrus and the Carpenter',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AzvP5QjeaUYpsj5ju0m5TQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-walrus-and-the-carpenter-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1597,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.66351, 'longitude': -122.38022},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4743 Ballard Ave NW',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98107',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['4743 Ballard Ave NW', 'Seattle, WA 98107']},
#   'phone': '+12063959227',
#   'display_phone': '(206) 395-9227',
#   'distance': 5402.217414076959},
#  {'id': 'rgkwLKTmZdj72S1KmEkENg',
#   'alias': 'zig-zag-cafe-seattle-2',
#   'name': 'Zig Zag Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GkTDqQt2b81unM_i2T9zoA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zig-zag-cafe-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1023,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6083803, 'longitude': -122.3414779},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1501 Western Ave',
#    'address2': 'Ste 202',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1501 Western Ave', 'Ste 202', 'Seattle, WA 98101']},
#   'phone': '+12066251146',
#   'display_phone': '(206) 625-1146',
#   'distance': 1946.7063797501626},
#  {'id': 'smOVPL87Q0XHACrVMPa8qw',
#   'alias': '8oz-burger-and-co-seattle',
#   'name': '8oz Burger & Co',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LnggdyxSd-aVe41dWJF2-Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/8oz-burger-and-co-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1618,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6131289631218,
#    'longitude': -122.321055232102},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1401 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1401 Broadway', 'Seattle, WA 98122']},
#   'phone': '+12064665989',
#   'display_phone': '(206) 466-5989',
#   'distance': 1743.9559568069214},
#  {'id': 'b1p0bl4BriQRfnn1mjHf5w',
#   'alias': 'top-pot-doughnuts-seattle',
#   'name': 'Top Pot Doughnuts',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IuvKNRbavtxPf2nLaHakzQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/top-pot-doughnuts-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1745,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'donuts', 'title': 'Donuts'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6151731973087, 'longitude': -122.34128517325},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '2124 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2124 5th Ave', 'Seattle, WA 98121']},
#   'phone': '+12067281966',
#   'display_phone': '(206) 728-1966',
#   'distance': 1218.7338291901015},
#  {'id': '1rkgyfwzXG7qSdVZdfRt7g',
#   'alias': 'roccos-seattle',
#   'name': "Rocco's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eIh2ft9YFIAigNtsi9ZlFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roccos-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1374,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6140031078304, 'longitude': -122.345133},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2228 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2228 2nd Ave', 'Seattle, WA 98121']},
#   'phone': '+12064482625',
#   'display_phone': '(206) 448-2625',
#   'distance': 1459.9772427162504},
#  {'id': 'P29VT5rdm1YGkaAB9XCn2w',
#   'alias': 'biscuit-and-bean-seattle-9',
#   'name': 'Biscuit and Bean',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bAMw0ZjVSR9gdTKiEIvC2g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/biscuit-and-bean-seattle-9?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 757,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6718, 'longitude': -122.3764655},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '5905 15th Ave NW',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98107',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['5905 15th Ave NW', 'Seattle, WA 98107']},
#   'phone': '+12064575735',
#   'display_phone': '(206) 457-5735',
#   'distance': 6000.843759824215},
#  {'id': 'MUo0UetYF961VH6cv8j56A',
#   'alias': 'museum-of-pop-culture-seattle-3',
#   'name': 'Museum of Pop Culture',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wpe0L66tg1LC5yYA-mjAcA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/museum-of-pop-culture-seattle-3?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1571,
#   'categories': [{'alias': 'museums', 'title': 'Museums'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.621486, 'longitude': -122.348124},
#   'transactions': [],
#   'location': {'address1': '325 5th Ave N',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98109',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['325 5th Ave N', 'Seattle, WA 98109']},
#   'phone': '+12067702700',
#   'display_phone': '(206) 770-2700',
#   'distance': 1041.6002630609094},
#  {'id': '0cqa2F_cfIjxAC3nqw__1w',
#   'alias': 'serious-pie-and-biscuit-seattle-6',
#   'name': 'Serious Pie & Biscuit',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/78alN8v6l0TU9PB6jT4AdQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/serious-pie-and-biscuit-seattle-6?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1704,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6221655931029,
#    'longitude': -122.338662374865},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '401 Westlake Ave N',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98109',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['401 Westlake Ave N', 'Seattle, WA 98109']},
#   'phone': '+12064360050',
#   'display_phone': '(206) 436-0050',
#   'distance': 432.0677812410876},
#  {'id': 'h1Q0Wkx5TUUZeVjJrXTwmQ',
#   'alias': 'chan-seattle-seattle-2',
#   'name': 'Chan Seattle',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VmCWBN6xBWySopG0kEzplw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chan-seattle-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 902,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6098823547363,
#    'longitude': -122.341438293457},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '86 Pine St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['86 Pine St', 'Seattle, WA 98101']},
#   'phone': '+12063543564',
#   'display_phone': '(206) 354-3564',
#   'distance': 1783.8238301371016},
#  {'id': 'ZCtSkAulGzhWd1o0oWbYgQ',
#   'alias': 'din-tai-fung-seattle-14',
#   'name': 'Din Tai Fung',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KqoBEe0fk70IPTCK3c2QAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/din-tai-fung-seattle-14?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1458,
#   'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#    {'alias': 'shanghainese', 'title': 'Shanghainese'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61289, 'longitude': -122.33531},
#   'transactions': ['restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '600 Pine St',
#    'address2': 'Ste 403',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['600 Pine St', 'Ste 403', 'Seattle, WA 98101']},
#   'phone': '+12066829888',
#   'display_phone': '(206) 682-9888',
#   'distance': 1399.1438872560698},
#  {'id': 'Gn5erxCRML47GgbGYdxzFA',
#   'alias': 'bongos-seattle',
#   'name': 'Bongos',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W_EcX7OwpL-BvarRW5NkrQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bongos-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 839,
#   'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#    {'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6767449533551,
#    'longitude': -122.346925400198},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '6501 Aurora Ave N',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98103',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['6501 Aurora Ave N', 'Seattle, WA 98103']},
#   'phone': '+12064208548',
#   'display_phone': '(206) 420-8548',
#   'distance': 5770.871794260582},
#  {'id': 'M5gjalaqrlkVm55RHqiaaA',
#   'alias': 'maneki-seattle',
#   'name': 'Maneki',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kAdVD_UCfRZdtA4hcKImXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maneki-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1158,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.59974, 'longitude': -122.32614},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '304 6th Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['304 6th Ave S', 'Seattle, WA 98104']},
#   'phone': '+12066222631',
#   'display_phone': '(206) 622-2631',
#   'distance': 2944.4581472591026},
#  {'id': 'vs5dhED5Yf8kqPp06OD2QQ',
#   'alias': 'momiji-seattle',
#   'name': 'Momiji',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5XslhP5lqCIQd7KUFV4HSg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/momiji-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1410,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61482, 'longitude': -122.31657},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1522 12th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1522 12th Ave', 'Seattle, WA 98122']},
#   'phone': '+12064574068',
#   'display_phone': '(206) 457-4068',
#   'distance': 1851.6920744376196},
#  {'id': 'cFTq5MmBDPb_VEqQXPw2Dw',
#   'alias': 'wasabi-sushi-and-izakaya-seattle',
#   'name': 'Wasabi Sushi & Izakaya',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7Wq6K5Sh7Xdp5AHtngLYlA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wasabi-sushi-and-izakaya-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1572,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'izakaya', 'title': 'Izakaya'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.614196, 'longitude': -122.346226},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2311 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2311 2nd Ave', 'Seattle, WA 98121']},
#   'phone': '+12064416044',
#   'display_phone': '(206) 441-6044',
#   'distance': 1484.0542206874866},
#  {'id': 'E0iowq7KQK987ad5vmzyUQ',
#   'alias': 'salt-and-straw-seattle-2',
#   'name': 'Salt & Straw',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cjvUB6uKZRDXV3EFdazjCw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/salt-and-straw-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 586,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6142143070702,
#    'longitude': -122.323235442336},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '714 E Pike St',
#    'address2': 'Ste A',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['714 E Pike St', 'Ste A', 'Seattle, WA 98122']},
#   'phone': '+12062584574',
#   'display_phone': '(206) 258-4574',
#   'distance': 1548.7722275901945},
#  {'id': 'PWKLXxGZI1On2kRcwM8Hxw',
#   'alias': 'rockcreek-seafood-and-spirits-seattle',
#   'name': 'RockCreek Seafood & Spirits',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cyk-n-xHnW9g-_7Bcjsu3g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rockcreek-seafood-and-spirits-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 920,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6594842489603,
#    'longitude': -122.349788737434},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '4300 Fremont Ave N',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98103',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['4300 Fremont Ave N', 'Seattle, WA 98103']},
#   'phone': '+12065577532',
#   'display_phone': '(206) 557-7532',
#   'distance': 3936.0230513661218},
#  {'id': '6OVriioGG7w7Nwq5Q25WtA',
#   'alias': 'portage-bay-cafe-roosevelt-seattle',
#   'name': 'Portage Bay Cafe - Roosevelt',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Iyxcf_g_Tst5wYqYULMyzw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/portage-bay-cafe-roosevelt-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 2337,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.65757, 'longitude': -122.3176},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4130 Roosevelt Way NE',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98105',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['4130 Roosevelt Way NE', 'Seattle, WA 98105']},
#   'phone': '+12065478230',
#   'display_phone': '(206) 547-8230',
#   'distance': 3840.226377247832},
#  {'id': 'W98DbPkYeu99IBqzTObJJw',
#   'alias': 'gelatiamo-seattle',
#   'name': 'Gelatiamo',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/77hxfyddZMJvJ5N1IcHVuw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gelatiamo-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 745,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#    {'alias': 'gelato', 'title': 'Gelato'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.60899, 'longitude': -122.33671},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1400 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1400 3rd Ave', 'Seattle, WA 98101']},
#   'phone': '+12064679563',
#   'display_phone': '(206) 467-9563',
#   'distance': 1830.604184400054},
#  {'id': 'ZLLOdh2C5WHJ7T4e3RGTcQ',
#   'alias': 'mr-gyros-seattle-2',
#   'name': 'Mr Gyros',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/On6_YkRUFKsAxEa6glycaw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mr-gyros-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1029,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6695873953204,
#    'longitude': -122.382009446032},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '5522 20th Ave NW',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98107',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['5522 20th Ave NW', 'Seattle, WA 98107']},
#   'phone': '+12067827777',
#   'display_phone': '(206) 782-7777',
#   'distance': 6021.137773786509},
#  {'id': 'BQhcvUAbrqzsLsew1STD-w',
#   'alias': 'skillet-capitol-hill-seattle-2',
#   'name': 'Skillet Capitol Hill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wLEt3DrpkgKoJ4a1bjyLRA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/skillet-capitol-hill-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1855,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.613138, 'longitude': -122.31386},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1400 E Union St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1400 E Union St', 'Seattle, WA 98122']},
#   'phone': '+12065122001',
#   'display_phone': '(206) 512-2001',
#   'distance': 2120.8570125459914},
#  {'id': 'iHG_OTRDZs3WyxVeDA_gKQ',
#   'alias': 'dahlia-lounge-seattle',
#   'name': 'Dahlia Lounge',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r376ZJ_YOUbDbOBco4f4Sw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dahlia-lounge-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1599,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61304, 'longitude': -122.34058},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2001 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2001 4th Ave', 'Seattle, WA 98121']},
#   'phone': '+12066824142',
#   'display_phone': '(206) 682-4142',
#   'distance': 1417.964960701809},
#  {'id': 'UzaMrsDMM7xmxtWLPTrmKw',
#   'alias': 'shaker-and-spear-seattle-2',
#   'name': 'Shaker & Spear',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VZDFdZ7l0NCm-AYnqp675g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shaker-and-spear-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 744,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.61203, 'longitude': -122.34165},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2000 2nd Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2000 2nd Ave', 'Seattle, WA 98121']},
#   'phone': '+12068261700',
#   'display_phone': '(206) 826-1700',
#   'distance': 1555.2383387148766},
#  {'id': 'BvOLqjt68GEJREOYQ_vdHw',
#   'alias': 'taylor-shellfish-farms-seattle-seattle',
#   'name': 'Taylor Shellfish Farms - Seattle',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KVIxhRZLWywqBTO3TjA9Zw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taylor-shellfish-farms-seattle-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1012,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.614652, 'longitude': -122.328081},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1521 Melrose Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1521 Melrose Ave', 'Seattle, WA 98122']},
#   'phone': '+12065014321',
#   'display_phone': '(206) 501-4321',
#   'distance': 1320.392388575357},
#  {'id': 'b4Iw-XvcstHPYaSIAsL0fg',
#   'alias': 'el-gaucho-seattle',
#   'name': 'El Gaucho',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/up4cI-knxXunR-Vw-LgVUg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-gaucho-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1180,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6147330738928,
#    'longitude': -122.349196290354},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '2505 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2505 1st Ave', 'Seattle, WA 98121']},
#   'phone': '+12067281337',
#   'display_phone': '(206) 728-1337',
#   'distance': 1569.739780540725},
#  {'id': '7Oj8IKp1pibP4huWecsQ6A',
#   'alias': 'quinns-seattle',
#   'name': "Quinn's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KOY48oWwqrkM1JNPXT0VlQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/quinns-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1305,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61386, 'longitude': -122.31922},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1001 E Pike St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1001 E Pike St', 'Seattle, WA 98122']},
#   'phone': '+12063257711',
#   'display_phone': '(206) 325-7711',
#   'distance': 1770.9111570197238},
#  {'id': '5hvXRsi_oep4ArIqKbeM_w',
#   'alias': 'petra-bistro-seattle',
#   'name': 'Petra Bistro',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VfKgsIk0rrMpb5b7WqrR2Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/petra-bistro-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1016,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'mideastern', 'title': 'Middle Eastern'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61669, 'longitude': -122.34653},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2501 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2501 4th Ave', 'Seattle, WA 98121']},
#   'phone': '+12067285389',
#   'display_phone': '(206) 728-5389',
#   'distance': 1275.0137402606615},
#  {'id': 'rXbU5HJx6mihqazytPTgXA',
#   'alias': 'kedai-makan-seattle-4',
#   'name': 'Kedai Makan',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PMqIAYAknTK01diJEspDOA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kedai-makan-seattle-4?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 870,
#   'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6179, 'longitude': -122.32658},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1802 Bellevue Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1802 Bellevue Ave', 'Seattle, WA 98122']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1073.0051178890512},
#  {'id': '2FS5eBVcFJ_W461ylUs38Q',
#   'alias': 'palisade-seattle',
#   'name': 'Palisade',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ps8n_cRcoA7YPEh0i2TyPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/palisade-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1421,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.630364, 'longitude': -122.3915012},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '2601 W Marina Pl',
#    'address2': '',
#    'address3': 'Elliott Bay Marina',
#    'city': 'Seattle',
#    'zip_code': '98199',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2601 W Marina Pl',
#     'Elliott Bay Marina',
#     'Seattle, WA 98199']},
#   'phone': '+12062851000',
#   'display_phone': '(206) 285-1000',
#   'distance': 4231.776516766492},
#  {'id': '8_oxyuITZ-1T3phGrgAbMg',
#   'alias': 'monorail-espresso-seattle',
#   'name': 'Monorail Espresso',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FHqmRjPV9qKWTFWUKDPkfw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/monorail-espresso-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 529,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.611, 'longitude': -122.33545},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '510 Pike St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['510 Pike St', 'Seattle, WA 98101']},
#   'phone': '+12064220736',
#   'display_phone': '(206) 422-0736',
#   'distance': 1596.7859859591706},
#  {'id': '45IC4gkYjabENFQEzYeqqA',
#   'alias': 'gas-works-park-seattle-2',
#   'name': 'Gas Works Park',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/q9u9GnrTRQI6G6SR2DvVSg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gas-works-park-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 601,
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.646241, 'longitude': -122.3337},
#   'transactions': [],
#   'location': {'address1': '2101 N Northlake Way',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98103',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2101 N Northlake Way', 'Seattle, WA 98103']},
#   'phone': '+12066844075',
#   'display_phone': '(206) 684-4075',
#   'distance': 2319.2625678528},
#  {'id': 'XTrf7pn2nbcNLgsYQtx4vg',
#   'alias': 'hello-robin-seattle',
#   'name': 'Hello Robin',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lrUtjgYCKJ5zTi5nl9gbgw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hello-robin-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 632,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6238087792208,
#    'longitude': -122.307136621784},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '522 19th Ave E',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98112',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['522 19th Ave E', 'Seattle, WA 98112']},
#   'phone': '+12067357970',
#   'display_phone': '(206) 735-7970',
#   'distance': 2133.948443594839},
#  {'id': 'FWQCmFEe74oh7UmSHjZ1LQ',
#   'alias': 'cafe-turko-seattle-4',
#   'name': 'Cafe Turko',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8X3BhpZF0OlS72yFGBa9Kg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cafe-turko-seattle-4?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 975,
#   'categories': [{'alias': 'halal', 'title': 'Halal'},
#    {'alias': 'turkish', 'title': 'Turkish'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6494089483896,
#    'longitude': -122.347989527251},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '750 N 34th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98103',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['750 N 34th St', 'Seattle, WA 98103']},
#   'phone': '+12062849954',
#   'display_phone': '(206) 284-9954',
#   'distance': 2826.6737973397244},
#  {'id': 'RwCpDB4C7CCFQvFxH1ve1g',
#   'alias': 'seattle-coffee-works-seattle',
#   'name': 'Seattle Coffee Works',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nDzPH0DZAzMI4GYlcseagw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/seattle-coffee-works-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 865,
#   'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6101133, 'longitude': -122.3405669},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '108 Pine St',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['108 Pine St', 'Seattle, WA 98101']},
#   'phone': '+12063408867',
#   'display_phone': '(206) 340-8867',
#   'distance': 1743.6115492452786},
#  {'id': '4IU-zvKxxScUhMg3hVo_FA',
#   'alias': 'hot-cakes-molten-chocolate-cakery-seattle',
#   'name': 'Hot Cakes Molten Chocolate Cakery',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XW0XE6xmATM2v02u3dDhJg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hot-cakes-molten-chocolate-cakery-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1272,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6680853271588, 'longitude': -122.38557639577},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5427 Ballard Ave NW',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98107',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['5427 Ballard Ave NW', 'Seattle, WA 98107']},
#   'phone': '+12064533792',
#   'display_phone': '(206) 453-3792',
#   'distance': 6047.702249489472},
#  {'id': 'qERtBPTw_lLv0fkxw3cRPw',
#   'alias': 'nue-seattle',
#   'name': 'Nue',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A0FKD9Gtv_xo2l_e9EiqAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nue-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 921,
#   'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61483, 'longitude': -122.3146},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1519 14th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1519 14th Ave', 'Seattle, WA 98122']},
#   'phone': '+12062570312',
#   'display_phone': '(206) 257-0312',
#   'distance': 1976.3336513402564},
#  {'id': 'aOCqNgTnTbdAbY61ZgRPaA',
#   'alias': 'musashis-seattle',
#   'name': "Musashi's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uoemSYcLTkk91GoSHbJhuA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/musashis-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1143,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.66161, 'longitude': -122.34047},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1400 N 45th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98103',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1400 N 45th St', 'Seattle, WA 98103']},
#   'phone': '+12066330212',
#   'display_phone': '(206) 633-0212',
#   'distance': 4040.7064913880117},
#  {'id': 'u_v3NLu8Iy_jaf5TkGPIGw',
#   'alias': 'royal-grinders-seattle-2',
#   'name': 'Royal Grinders',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wk-HY9gB2s6ad3DZOC0p3g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/royal-grinders-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 627,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'},
#    {'alias': 'vegan', 'title': 'Vegan'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6513, 'longitude': -122.35078},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3526 Fremont Pl N',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98103',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['3526 Fremont Pl N', 'Seattle, WA 98103']},
#   'phone': '+12062358529',
#   'display_phone': '(206) 235-8529',
#   'distance': 3093.0289833707075},
#  {'id': '1pq3kaUmxxRKDxI6GDtQcg',
#   'alias': 'frankie-and-jos-capitol-hill-seattle',
#   'name': "Frankie & Jo's Capitol Hill",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2TomgvirkLHvmCKTf81tZg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/frankie-and-jos-capitol-hill-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 534,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.612983211875, 'longitude': -122.319105863571},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1010 E Union St',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1010 E Union St', 'Seattle, WA 98122']},
#   'phone': '+12065574603',
#   'display_phone': '(206) 557-4603',
#   'distance': 1850.3744560981916},
#  {'id': '-ofDNmj8r_F875FiZr9G8w',
#   'alias': 'witness-seattle',
#   'name': 'Witness',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zTdyiJ42yBw0S5qi-jWwxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/witness-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 776,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6225508133524,
#    'longitude': -122.320680460381},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '410 Broadway E',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98102',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['410 Broadway E', 'Seattle, WA 98102']},
#   'phone': '+12063290248',
#   'display_phone': '(206) 329-0248',
#   'distance': 1156.2676526119806},
#  {'id': 'VA4pB-l76sunIqCFFP-6lg',
#   'alias': 'geraldines-counter-seattle-2',
#   'name': "Geraldine's Counter",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IOczfghNEKyXPIizJD1Z5A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/geraldines-counter-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1209,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'diners', 'title': 'Diners'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.5580008, 'longitude': -122.2848526},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4872 Rainier Ave S',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98118',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['4872 Rainier Ave S', 'Seattle, WA 98118']},
#   'phone': '+12067232080',
#   'display_phone': '(206) 723-2080',
#   'distance': 8404.148260334607},
#  {'id': '7DwqCE8mHqlDw_oZ2VfdBg',
#   'alias': 'molly-moons-homemade-ice-cream-seattle-6',
#   'name': "Molly Moon's Homemade Ice Cream",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fGmAw2uE2tywr2jE7viwGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/molly-moons-homemade-ice-cream-seattle-6?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1241,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6614912966508,
#    'longitude': -122.338043573655},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1622 1/2 N 45th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98103',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1622 1/2 N 45th St', 'Seattle, WA 98103']},
#   'phone': '+12065475105',
#   'display_phone': '(206) 547-5105',
#   'distance': 4015.534151237254},
#  {'id': 'ANRznMzskndUpHA93KdEbA',
#   'alias': 'café-presse-seattle-2',
#   'name': 'Café Presse',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3KLdYYBJeJibK4fSJJKAHw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caf%C3%A9-presse-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 1150,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6120529174805,
#    'longitude': -122.317108154297},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1117 12th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1117 12th Ave', 'Seattle, WA 98122']},
#   'phone': '+12067097674',
#   'display_phone': '(206) 709-7674',
#   'distance': 2025.0169941039107},
#  {'id': 'bB9mbLCKSvXltK8za8nK0A',
#   'alias': 'matts-in-the-market-seattle',
#   'name': "Matt's in the Market",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6cnJUwXtwire0DKlsrTTTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/matts-in-the-market-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 998,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.60888, 'longitude': -122.34036},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '94 Pike St',
#    'address2': 'Ste 32',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['94 Pike St', 'Ste 32', 'Seattle, WA 98101']},
#   'phone': '+12064677909',
#   'display_phone': '(206) 467-7909',
#   'distance': 1874.6459036561484},
#  {'id': 'z3B84RJM47aCnfZ69ai8cA',
#   'alias': 'the-capital-grille-seattle',
#   'name': 'The Capital Grille',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x559sKUPkItRBQ-OU5-tVA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-capital-grille-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 881,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.60826, 'longitude': -122.33538},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '1301 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1301 4th Ave', 'Seattle, WA 98101']},
#   'phone': '+12063820900',
#   'display_phone': '(206) 382-0900',
#   'distance': 1904.6766127481496},
#  {'id': 'Y-OgQKqreMaajTUCPbLPKg',
#   'alias': 'tsukushinbo-seattle',
#   'name': 'Tsukushinbo',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r6mFftGhUVvZjSu67PwSVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tsukushinbo-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg',
#   'review_count': 889,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.59985, 'longitude': -122.32681},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '515 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['515 S Main St', 'Seattle, WA 98104']},
#   'phone': '+12064674004',
#   'display_phone': '(206) 467-4004',
#   'distance': 2916.7718796688164}]

# %%
for biz in business_data['businesses']:
    print(biz)
# Out:
# {'id': '7F473Qfy0eRD6_5lgfWTSA', 'alias': 'taste-of-india-seattle', 'name': 'Taste of India', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HW44UOamjSJ86E2gd0XzTQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/taste-of-india-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1530, 'categories': [{'alias': 'indpak', 'title': 'Indian'}], 'rating': 4.5, 'coordinates': {'latitude': 47.669083, 'longitude': -122.317484}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '5517 Roosevelt Way NE', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98105', 'country': 'US', 'state': 'WA', 'display_address': ['5517 Roosevelt Way NE', 'Seattle, WA 98105']}, 'phone': '+12065281575', 'display_phone': '(206) 528-1575', 'distance': 5039.494501568876}
# {'id': 'FrHhYevaOhs40xpuOpQiHg', 'alias': 'canlis-seattle', 'name': 'Canlis', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ckDxHbNcjdkR4Kr1kIE-vg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/canlis-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1456, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'seafood', 'title': 'Seafood'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6430119, 'longitude': -122.3467676}, 'transactions': ['pickup'], 'price': '$$$$', 'location': {'address1': '2576 Aurora Ave N', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98109', 'country': 'US', 'state': 'WA', 'display_address': ['2576 Aurora Ave N', 'Seattle, WA 98109']}, 'phone': '+12062833313', 'display_phone': '(206) 283-3313', 'distance': 2130.343205095282}
# {'id': 'a9iLwBAri52khGIR_rrUkw', 'alias': 'dahlia-bakery-seattle', 'name': 'Dahlia Bakery', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3w1ntQo9OUE8IwfLIheg_w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/dahlia-bakery-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 996, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6131855205192, 'longitude': -122.340556830168}, 'transactions': ['pickup'], 'price': '$', 'location': {'address1': '2001 4th Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98121', 'country': 'US', 'state': 'WA', 'display_address': ['2001 4th Ave', 'Seattle, WA 98121']}, 'phone': '+12064414540', 'display_phone': '(206) 441-4540', 'distance': 1411.9134769881557}
# {'id': 'seXhmf0ry1gFsmLUDues5w', 'alias': 'honeyhole-sandwiches-seattle-2', 'name': 'HoneyHole Sandwiches', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gHbZaDZtB4UWawVP0b89Qg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/honeyhole-sandwiches-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1383, 'categories': [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 4.0, 'coordinates': {'latitude': 47.61393, 'longitude': -122.3232}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '703 E Pike St', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['703 E Pike St', 'Seattle, WA 98122']}, 'phone': '+12067091399', 'display_phone': '(206) 709-1399', 'distance': 1579.7786563851796}
# {'id': '1EFQ8ePAtsgqWc3VyneBMw', 'alias': 'daily-dozen-doughnut-seattle', 'name': 'Daily Dozen Doughnut', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h8OKoRFyC14IvZR8pO1exA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/daily-dozen-doughnut-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1002, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'foodstands', 'title': 'Food Stands'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6086751, 'longitude': -122.3402434}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '93 Pike St', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98101', 'country': 'US', 'state': 'WA', 'display_address': ['93 Pike St', 'Seattle, WA 98101']}, 'phone': '+12064677769', 'display_phone': '(206) 467-7769', 'distance': 1898.6275827863913}
# {'id': '9OXEAAPONxcA2PQO75fnJQ', 'alias': 'the-walrus-and-the-carpenter-seattle', 'name': 'The Walrus and the Carpenter', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AzvP5QjeaUYpsj5ju0m5TQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-walrus-and-the-carpenter-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1597, 'categories': [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}], 'rating': 4.0, 'coordinates': {'latitude': 47.66351, 'longitude': -122.38022}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '4743 Ballard Ave NW', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98107', 'country': 'US', 'state': 'WA', 'display_address': ['4743 Ballard Ave NW', 'Seattle, WA 98107']}, 'phone': '+12063959227', 'display_phone': '(206) 395-9227', 'distance': 5402.217414076959}
# {'id': 'rgkwLKTmZdj72S1KmEkENg', 'alias': 'zig-zag-cafe-seattle-2', 'name': 'Zig Zag Cafe', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GkTDqQt2b81unM_i2T9zoA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/zig-zag-cafe-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1023, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6083803, 'longitude': -122.3414779}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1501 Western Ave', 'address2': 'Ste 202', 'address3': '', 'city': 'Seattle', 'zip_code': '98101', 'country': 'US', 'state': 'WA', 'display_address': ['1501 Western Ave', 'Ste 202', 'Seattle, WA 98101']}, 'phone': '+12066251146', 'display_phone': '(206) 625-1146', 'distance': 1946.7063797501626}
# {'id': 'smOVPL87Q0XHACrVMPa8qw', 'alias': '8oz-burger-and-co-seattle', 'name': '8oz Burger & Co', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LnggdyxSd-aVe41dWJF2-Q/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/8oz-burger-and-co-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1618, 'categories': [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'salad', 'title': 'Salad'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6131289631218, 'longitude': -122.321055232102}, 'transactions': [], 'price': '$$', 'location': {'address1': '1401 Broadway', 'address2': None, 'address3': '', 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['1401 Broadway', 'Seattle, WA 98122']}, 'phone': '+12064665989', 'display_phone': '(206) 466-5989', 'distance': 1743.9559568069214}
# {'id': 'b1p0bl4BriQRfnn1mjHf5w', 'alias': 'top-pot-doughnuts-seattle', 'name': 'Top Pot Doughnuts', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IuvKNRbavtxPf2nLaHakzQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/top-pot-doughnuts-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1745, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'donuts', 'title': 'Donuts'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6151731973087, 'longitude': -122.34128517325}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '2124 5th Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98121', 'country': 'US', 'state': 'WA', 'display_address': ['2124 5th Ave', 'Seattle, WA 98121']}, 'phone': '+12067281966', 'display_phone': '(206) 728-1966', 'distance': 1218.7338291901015}
# {'id': '1rkgyfwzXG7qSdVZdfRt7g', 'alias': 'roccos-seattle', 'name': "Rocco's", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eIh2ft9YFIAigNtsi9ZlFA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/roccos-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1374, 'categories': [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'pizza', 'title': 'Pizza'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6140031078304, 'longitude': -122.345133}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '2228 2nd Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98121', 'country': 'US', 'state': 'WA', 'display_address': ['2228 2nd Ave', 'Seattle, WA 98121']}, 'phone': '+12064482625', 'display_phone': '(206) 448-2625', 'distance': 1459.9772427162504}
# {'id': 'P29VT5rdm1YGkaAB9XCn2w', 'alias': 'biscuit-and-bean-seattle-9', 'name': 'Biscuit and Bean', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bAMw0ZjVSR9gdTKiEIvC2g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/biscuit-and-bean-seattle-9?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 757, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6718, 'longitude': -122.3764655}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '5905 15th Ave NW', 'address2': None, 'address3': '', 'city': 'Seattle', 'zip_code': '98107', 'country': 'US', 'state': 'WA', 'display_address': ['5905 15th Ave NW', 'Seattle, WA 98107']}, 'phone': '+12064575735', 'display_phone': '(206) 457-5735', 'distance': 6000.843759824215}
# {'id': 'MUo0UetYF961VH6cv8j56A', 'alias': 'museum-of-pop-culture-seattle-3', 'name': 'Museum of Pop Culture', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wpe0L66tg1LC5yYA-mjAcA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/museum-of-pop-culture-seattle-3?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1571, 'categories': [{'alias': 'museums', 'title': 'Museums'}], 'rating': 4.0, 'coordinates': {'latitude': 47.621486, 'longitude': -122.348124}, 'transactions': [], 'location': {'address1': '325 5th Ave N', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98109', 'country': 'US', 'state': 'WA', 'display_address': ['325 5th Ave N', 'Seattle, WA 98109']}, 'phone': '+12067702700', 'display_phone': '(206) 770-2700', 'distance': 1041.6002630609094}
# {'id': '0cqa2F_cfIjxAC3nqw__1w', 'alias': 'serious-pie-and-biscuit-seattle-6', 'name': 'Serious Pie & Biscuit', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/78alN8v6l0TU9PB6jT4AdQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/serious-pie-and-biscuit-seattle-6?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1704, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6221655931029, 'longitude': -122.338662374865}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '401 Westlake Ave N', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98109', 'country': 'US', 'state': 'WA', 'display_address': ['401 Westlake Ave N', 'Seattle, WA 98109']}, 'phone': '+12064360050', 'display_phone': '(206) 436-0050', 'distance': 432.0677812410876}
# {'id': 'h1Q0Wkx5TUUZeVjJrXTwmQ', 'alias': 'chan-seattle-seattle-2', 'name': 'Chan Seattle', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VmCWBN6xBWySopG0kEzplw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/chan-seattle-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 902, 'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'korean', 'title': 'Korean'}, {'alias': 'gastropubs', 'title': 'Gastropubs'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6098823547363, 'longitude': -122.341438293457}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '86 Pine St', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98101', 'country': 'US', 'state': 'WA', 'display_address': ['86 Pine St', 'Seattle, WA 98101']}, 'phone': '+12063543564', 'display_phone': '(206) 354-3564', 'distance': 1783.8238301371016}
# {'id': 'ZCtSkAulGzhWd1o0oWbYgQ', 'alias': 'din-tai-fung-seattle-14', 'name': 'Din Tai Fung', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KqoBEe0fk70IPTCK3c2QAQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/din-tai-fung-seattle-14?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1458, 'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}, {'alias': 'shanghainese', 'title': 'Shanghainese'}, {'alias': 'dimsum', 'title': 'Dim Sum'}], 'rating': 4.0, 'coordinates': {'latitude': 47.61289, 'longitude': -122.33531}, 'transactions': ['restaurant_reservation', 'delivery'], 'price': '$$', 'location': {'address1': '600 Pine St', 'address2': 'Ste 403', 'address3': None, 'city': 'Seattle', 'zip_code': '98101', 'country': 'US', 'state': 'WA', 'display_address': ['600 Pine St', 'Ste 403', 'Seattle, WA 98101']}, 'phone': '+12066829888', 'display_phone': '(206) 682-9888', 'distance': 1399.1438872560698}
# {'id': 'Gn5erxCRML47GgbGYdxzFA', 'alias': 'bongos-seattle', 'name': 'Bongos', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W_EcX7OwpL-BvarRW5NkrQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bongos-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 839, 'categories': [{'alias': 'cuban', 'title': 'Cuban'}, {'alias': 'caribbean', 'title': 'Caribbean'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6767449533551, 'longitude': -122.346925400198}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '6501 Aurora Ave N', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98103', 'country': 'US', 'state': 'WA', 'display_address': ['6501 Aurora Ave N', 'Seattle, WA 98103']}, 'phone': '+12064208548', 'display_phone': '(206) 420-8548', 'distance': 5770.871794260582}
# {'id': 'M5gjalaqrlkVm55RHqiaaA', 'alias': 'maneki-seattle', 'name': 'Maneki', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kAdVD_UCfRZdtA4hcKImXQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/maneki-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1158, 'categories': [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'sushi', 'title': 'Sushi Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 47.59974, 'longitude': -122.32614}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '304 6th Ave S', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98104', 'country': 'US', 'state': 'WA', 'display_address': ['304 6th Ave S', 'Seattle, WA 98104']}, 'phone': '+12066222631', 'display_phone': '(206) 622-2631', 'distance': 2944.4581472591026}
# {'id': 'vs5dhED5Yf8kqPp06OD2QQ', 'alias': 'momiji-seattle', 'name': 'Momiji', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5XslhP5lqCIQd7KUFV4HSg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/momiji-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1410, 'categories': [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}], 'rating': 4.0, 'coordinates': {'latitude': 47.61482, 'longitude': -122.31657}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1522 12th Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['1522 12th Ave', 'Seattle, WA 98122']}, 'phone': '+12064574068', 'display_phone': '(206) 457-4068', 'distance': 1851.6920744376196}
# {'id': 'cFTq5MmBDPb_VEqQXPw2Dw', 'alias': 'wasabi-sushi-and-izakaya-seattle', 'name': 'Wasabi Sushi & Izakaya', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7Wq6K5Sh7Xdp5AHtngLYlA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/wasabi-sushi-and-izakaya-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1572, 'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'izakaya', 'title': 'Izakaya'}, {'alias': 'ramen', 'title': 'Ramen'}], 'rating': 4.0, 'coordinates': {'latitude': 47.614196, 'longitude': -122.346226}, 'transactions': ['restaurant_reservation', 'delivery', 'pickup'], 'price': '$$', 'location': {'address1': '2311 2nd Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98121', 'country': 'US', 'state': 'WA', 'display_address': ['2311 2nd Ave', 'Seattle, WA 98121']}, 'phone': '+12064416044', 'display_phone': '(206) 441-6044', 'distance': 1484.0542206874866}
# {'id': 'E0iowq7KQK987ad5vmzyUQ', 'alias': 'salt-and-straw-seattle-2', 'name': 'Salt & Straw', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cjvUB6uKZRDXV3EFdazjCw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/salt-and-straw-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 586, 'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6142143070702, 'longitude': -122.323235442336}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '714 E Pike St', 'address2': 'Ste A', 'address3': None, 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['714 E Pike St', 'Ste A', 'Seattle, WA 98122']}, 'phone': '+12062584574', 'display_phone': '(206) 258-4574', 'distance': 1548.7722275901945}
# {'id': 'PWKLXxGZI1On2kRcwM8Hxw', 'alias': 'rockcreek-seafood-and-spirits-seattle', 'name': 'RockCreek Seafood & Spirits', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cyk-n-xHnW9g-_7Bcjsu3g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/rockcreek-seafood-and-spirits-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 920, 'categories': [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6594842489603, 'longitude': -122.349788737434}, 'transactions': ['delivery'], 'price': '$$$', 'location': {'address1': '4300 Fremont Ave N', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98103', 'country': 'US', 'state': 'WA', 'display_address': ['4300 Fremont Ave N', 'Seattle, WA 98103']}, 'phone': '+12065577532', 'display_phone': '(206) 557-7532', 'distance': 3936.0230513661218}
# {'id': '6OVriioGG7w7Nwq5Q25WtA', 'alias': 'portage-bay-cafe-roosevelt-seattle', 'name': 'Portage Bay Cafe - Roosevelt', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Iyxcf_g_Tst5wYqYULMyzw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/portage-bay-cafe-roosevelt-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 2337, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'cafes', 'title': 'Cafes'}], 'rating': 4.0, 'coordinates': {'latitude': 47.65757, 'longitude': -122.3176}, 'transactions': ['restaurant_reservation', 'delivery', 'pickup'], 'price': '$$', 'location': {'address1': '4130 Roosevelt Way NE', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98105', 'country': 'US', 'state': 'WA', 'display_address': ['4130 Roosevelt Way NE', 'Seattle, WA 98105']}, 'phone': '+12065478230', 'display_phone': '(206) 547-8230', 'distance': 3840.226377247832}
# {'id': 'W98DbPkYeu99IBqzTObJJw', 'alias': 'gelatiamo-seattle', 'name': 'Gelatiamo', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/77hxfyddZMJvJ5N1IcHVuw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/gelatiamo-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 745, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'gelato', 'title': 'Gelato'}], 'rating': 4.5, 'coordinates': {'latitude': 47.60899, 'longitude': -122.33671}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '1400 3rd Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98101', 'country': 'US', 'state': 'WA', 'display_address': ['1400 3rd Ave', 'Seattle, WA 98101']}, 'phone': '+12064679563', 'display_phone': '(206) 467-9563', 'distance': 1830.604184400054}
# {'id': 'ZLLOdh2C5WHJ7T4e3RGTcQ', 'alias': 'mr-gyros-seattle-2', 'name': 'Mr Gyros', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/On6_YkRUFKsAxEa6glycaw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mr-gyros-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1029, 'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6695873953204, 'longitude': -122.382009446032}, 'transactions': ['delivery', 'pickup'], 'price': '$', 'location': {'address1': '5522 20th Ave NW', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98107', 'country': 'US', 'state': 'WA', 'display_address': ['5522 20th Ave NW', 'Seattle, WA 98107']}, 'phone': '+12067827777', 'display_phone': '(206) 782-7777', 'distance': 6021.137773786509}
# {'id': 'BQhcvUAbrqzsLsew1STD-w', 'alias': 'skillet-capitol-hill-seattle-2', 'name': 'Skillet Capitol Hill', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wLEt3DrpkgKoJ4a1bjyLRA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/skillet-capitol-hill-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1855, 'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'newamerican', 'title': 'American (New)'}], 'rating': 4.0, 'coordinates': {'latitude': 47.613138, 'longitude': -122.31386}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1400 E Union St', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['1400 E Union St', 'Seattle, WA 98122']}, 'phone': '+12065122001', 'display_phone': '(206) 512-2001', 'distance': 2120.8570125459914}
# {'id': 'iHG_OTRDZs3WyxVeDA_gKQ', 'alias': 'dahlia-lounge-seattle', 'name': 'Dahlia Lounge', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r376ZJ_YOUbDbOBco4f4Sw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/dahlia-lounge-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1599, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.0, 'coordinates': {'latitude': 47.61304, 'longitude': -122.34058}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '2001 4th Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98121', 'country': 'US', 'state': 'WA', 'display_address': ['2001 4th Ave', 'Seattle, WA 98121']}, 'phone': '+12066824142', 'display_phone': '(206) 682-4142', 'distance': 1417.964960701809}
# {'id': 'UzaMrsDMM7xmxtWLPTrmKw', 'alias': 'shaker-and-spear-seattle-2', 'name': 'Shaker & Spear', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VZDFdZ7l0NCm-AYnqp675g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/shaker-and-spear-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 744, 'categories': [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.5, 'coordinates': {'latitude': 47.61203, 'longitude': -122.34165}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '2000 2nd Ave', 'address2': None, 'address3': None, 'city': 'Seattle', 'zip_code': '98121', 'country': 'US', 'state': 'WA', 'display_address': ['2000 2nd Ave', 'Seattle, WA 98121']}, 'phone': '+12068261700', 'display_phone': '(206) 826-1700', 'distance': 1555.2383387148766}
# {'id': 'BvOLqjt68GEJREOYQ_vdHw', 'alias': 'taylor-shellfish-farms-seattle-seattle', 'name': 'Taylor Shellfish Farms - Seattle', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KVIxhRZLWywqBTO3TjA9Zw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/taylor-shellfish-farms-seattle-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1012, 'categories': [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'raw_food', 'title': 'Live/Raw Food'}], 'rating': 4.0, 'coordinates': {'latitude': 47.614652, 'longitude': -122.328081}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1521 Melrose Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['1521 Melrose Ave', 'Seattle, WA 98122']}, 'phone': '+12065014321', 'display_phone': '(206) 501-4321', 'distance': 1320.392388575357}
# {'id': 'b4Iw-XvcstHPYaSIAsL0fg', 'alias': 'el-gaucho-seattle', 'name': 'El Gaucho', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/up4cI-knxXunR-Vw-LgVUg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/el-gaucho-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1180, 'categories': [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6147330738928, 'longitude': -122.349196290354}, 'transactions': [], 'price': '$$$$', 'location': {'address1': '2505 1st Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98121', 'country': 'US', 'state': 'WA', 'display_address': ['2505 1st Ave', 'Seattle, WA 98121']}, 'phone': '+12067281337', 'display_phone': '(206) 728-1337', 'distance': 1569.739780540725}
# {'id': '7Oj8IKp1pibP4huWecsQ6A', 'alias': 'quinns-seattle', 'name': "Quinn's", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KOY48oWwqrkM1JNPXT0VlQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/quinns-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1305, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'pubs', 'title': 'Pubs'}], 'rating': 4.0, 'coordinates': {'latitude': 47.61386, 'longitude': -122.31922}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1001 E Pike St', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['1001 E Pike St', 'Seattle, WA 98122']}, 'phone': '+12063257711', 'display_phone': '(206) 325-7711', 'distance': 1770.9111570197238}
# {'id': '5hvXRsi_oep4ArIqKbeM_w', 'alias': 'petra-bistro-seattle', 'name': 'Petra Bistro', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VfKgsIk0rrMpb5b7WqrR2Q/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/petra-bistro-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1016, 'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'greek', 'title': 'Greek'}], 'rating': 4.0, 'coordinates': {'latitude': 47.61669, 'longitude': -122.34653}, 'transactions': ['restaurant_reservation', 'delivery', 'pickup'], 'price': '$$', 'location': {'address1': '2501 4th Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98121', 'country': 'US', 'state': 'WA', 'display_address': ['2501 4th Ave', 'Seattle, WA 98121']}, 'phone': '+12067285389', 'display_phone': '(206) 728-5389', 'distance': 1275.0137402606615}
# {'id': 'rXbU5HJx6mihqazytPTgXA', 'alias': 'kedai-makan-seattle-4', 'name': 'Kedai Makan', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PMqIAYAknTK01diJEspDOA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/kedai-makan-seattle-4?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 870, 'categories': [{'alias': 'malaysian', 'title': 'Malaysian'}, {'alias': 'noodles', 'title': 'Noodles'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6179, 'longitude': -122.32658}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1802 Bellevue Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['1802 Bellevue Ave', 'Seattle, WA 98122']}, 'phone': '', 'display_phone': '', 'distance': 1073.0051178890512}
# {'id': '2FS5eBVcFJ_W461ylUs38Q', 'alias': 'palisade-seattle', 'name': 'Palisade', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ps8n_cRcoA7YPEh0i2TyPA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/palisade-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1421, 'categories': [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}], 'rating': 4.0, 'coordinates': {'latitude': 47.630364, 'longitude': -122.3915012}, 'transactions': [], 'price': '$$$', 'location': {'address1': '2601 W Marina Pl', 'address2': '', 'address3': 'Elliott Bay Marina', 'city': 'Seattle', 'zip_code': '98199', 'country': 'US', 'state': 'WA', 'display_address': ['2601 W Marina Pl', 'Elliott Bay Marina', 'Seattle, WA 98199']}, 'phone': '+12062851000', 'display_phone': '(206) 285-1000', 'distance': 4231.776516766492}
# {'id': '8_oxyuITZ-1T3phGrgAbMg', 'alias': 'monorail-espresso-seattle', 'name': 'Monorail Espresso', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FHqmRjPV9qKWTFWUKDPkfw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/monorail-espresso-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 529, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}], 'rating': 4.5, 'coordinates': {'latitude': 47.611, 'longitude': -122.33545}, 'transactions': [], 'price': '$', 'location': {'address1': '510 Pike St', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98101', 'country': 'US', 'state': 'WA', 'display_address': ['510 Pike St', 'Seattle, WA 98101']}, 'phone': '+12064220736', 'display_phone': '(206) 422-0736', 'distance': 1596.7859859591706}
# {'id': '45IC4gkYjabENFQEzYeqqA', 'alias': 'gas-works-park-seattle-2', 'name': 'Gas Works Park', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/q9u9GnrTRQI6G6SR2DvVSg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/gas-works-park-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 601, 'categories': [{'alias': 'parks', 'title': 'Parks'}], 'rating': 4.5, 'coordinates': {'latitude': 47.646241, 'longitude': -122.3337}, 'transactions': [], 'location': {'address1': '2101 N Northlake Way', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98103', 'country': 'US', 'state': 'WA', 'display_address': ['2101 N Northlake Way', 'Seattle, WA 98103']}, 'phone': '+12066844075', 'display_phone': '(206) 684-4075', 'distance': 2319.2625678528}
# {'id': 'XTrf7pn2nbcNLgsYQtx4vg', 'alias': 'hello-robin-seattle', 'name': 'Hello Robin', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lrUtjgYCKJ5zTi5nl9gbgw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hello-robin-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 632, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6238087792208, 'longitude': -122.307136621784}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '522 19th Ave E', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98112', 'country': 'US', 'state': 'WA', 'display_address': ['522 19th Ave E', 'Seattle, WA 98112']}, 'phone': '+12067357970', 'display_phone': '(206) 735-7970', 'distance': 2133.948443594839}
# {'id': 'FWQCmFEe74oh7UmSHjZ1LQ', 'alias': 'cafe-turko-seattle-4', 'name': 'Cafe Turko', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8X3BhpZF0OlS72yFGBa9Kg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/cafe-turko-seattle-4?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 975, 'categories': [{'alias': 'halal', 'title': 'Halal'}, {'alias': 'turkish', 'title': 'Turkish'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6494089483896, 'longitude': -122.347989527251}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '750 N 34th St', 'address2': None, 'address3': '', 'city': 'Seattle', 'zip_code': '98103', 'country': 'US', 'state': 'WA', 'display_address': ['750 N 34th St', 'Seattle, WA 98103']}, 'phone': '+12062849954', 'display_phone': '(206) 284-9954', 'distance': 2826.6737973397244}
# {'id': 'RwCpDB4C7CCFQvFxH1ve1g', 'alias': 'seattle-coffee-works-seattle', 'name': 'Seattle Coffee Works', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nDzPH0DZAzMI4GYlcseagw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/seattle-coffee-works-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 865, 'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6101133, 'longitude': -122.3405669}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '108 Pine St', 'address2': None, 'address3': '', 'city': 'Seattle', 'zip_code': '98101', 'country': 'US', 'state': 'WA', 'display_address': ['108 Pine St', 'Seattle, WA 98101']}, 'phone': '+12063408867', 'display_phone': '(206) 340-8867', 'distance': 1743.6115492452786}
# {'id': '4IU-zvKxxScUhMg3hVo_FA', 'alias': 'hot-cakes-molten-chocolate-cakery-seattle', 'name': 'Hot Cakes Molten Chocolate Cakery', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XW0XE6xmATM2v02u3dDhJg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hot-cakes-molten-chocolate-cakery-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1272, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6680853271588, 'longitude': -122.38557639577}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '5427 Ballard Ave NW', 'address2': None, 'address3': '', 'city': 'Seattle', 'zip_code': '98107', 'country': 'US', 'state': 'WA', 'display_address': ['5427 Ballard Ave NW', 'Seattle, WA 98107']}, 'phone': '+12064533792', 'display_phone': '(206) 453-3792', 'distance': 6047.702249489472}
# {'id': 'qERtBPTw_lLv0fkxw3cRPw', 'alias': 'nue-seattle', 'name': 'Nue', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A0FKD9Gtv_xo2l_e9EiqAw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/nue-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 921, 'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.0, 'coordinates': {'latitude': 47.61483, 'longitude': -122.3146}, 'transactions': ['restaurant_reservation', 'delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1519 14th Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['1519 14th Ave', 'Seattle, WA 98122']}, 'phone': '+12062570312', 'display_phone': '(206) 257-0312', 'distance': 1976.3336513402564}
# {'id': 'aOCqNgTnTbdAbY61ZgRPaA', 'alias': 'musashis-seattle', 'name': "Musashi's", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uoemSYcLTkk91GoSHbJhuA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/musashis-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1143, 'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'japanese', 'title': 'Japanese'}], 'rating': 4.0, 'coordinates': {'latitude': 47.66161, 'longitude': -122.34047}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1400 N 45th St', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98103', 'country': 'US', 'state': 'WA', 'display_address': ['1400 N 45th St', 'Seattle, WA 98103']}, 'phone': '+12066330212', 'display_phone': '(206) 633-0212', 'distance': 4040.7064913880117}
# {'id': 'u_v3NLu8Iy_jaf5TkGPIGw', 'alias': 'royal-grinders-seattle-2', 'name': 'Royal Grinders', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wk-HY9gB2s6ad3DZOC0p3g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/royal-grinders-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 627, 'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'vegan', 'title': 'Vegan'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6513, 'longitude': -122.35078}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '3526 Fremont Pl N', 'address2': None, 'address3': '', 'city': 'Seattle', 'zip_code': '98103', 'country': 'US', 'state': 'WA', 'display_address': ['3526 Fremont Pl N', 'Seattle, WA 98103']}, 'phone': '+12062358529', 'display_phone': '(206) 235-8529', 'distance': 3093.0289833707075}
# {'id': '1pq3kaUmxxRKDxI6GDtQcg', 'alias': 'frankie-and-jos-capitol-hill-seattle', 'name': "Frankie & Jo's Capitol Hill", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2TomgvirkLHvmCKTf81tZg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/frankie-and-jos-capitol-hill-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 534, 'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}], 'rating': 4.5, 'coordinates': {'latitude': 47.612983211875, 'longitude': -122.319105863571}, 'transactions': [], 'price': '$$', 'location': {'address1': '1010 E Union St', 'address2': '', 'address3': None, 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['1010 E Union St', 'Seattle, WA 98122']}, 'phone': '+12065574603', 'display_phone': '(206) 557-4603', 'distance': 1850.3744560981916}
# {'id': '-ofDNmj8r_F875FiZr9G8w', 'alias': 'witness-seattle', 'name': 'Witness', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zTdyiJ42yBw0S5qi-jWwxA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/witness-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 776, 'categories': [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}], 'rating': 4.5, 'coordinates': {'latitude': 47.6225508133524, 'longitude': -122.320680460381}, 'transactions': [], 'price': '$$', 'location': {'address1': '410 Broadway E', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98102', 'country': 'US', 'state': 'WA', 'display_address': ['410 Broadway E', 'Seattle, WA 98102']}, 'phone': '+12063290248', 'display_phone': '(206) 329-0248', 'distance': 1156.2676526119806}
# {'id': 'VA4pB-l76sunIqCFFP-6lg', 'alias': 'geraldines-counter-seattle-2', 'name': "Geraldine's Counter", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IOczfghNEKyXPIizJD1Z5A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/geraldines-counter-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1209, 'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'diners', 'title': 'Diners'}], 'rating': 4.0, 'coordinates': {'latitude': 47.5580008, 'longitude': -122.2848526}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '4872 Rainier Ave S', 'address2': None, 'address3': '', 'city': 'Seattle', 'zip_code': '98118', 'country': 'US', 'state': 'WA', 'display_address': ['4872 Rainier Ave S', 'Seattle, WA 98118']}, 'phone': '+12067232080', 'display_phone': '(206) 723-2080', 'distance': 8404.148260334607}
# {'id': '7DwqCE8mHqlDw_oZ2VfdBg', 'alias': 'molly-moons-homemade-ice-cream-seattle-6', 'name': "Molly Moon's Homemade Ice Cream", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fGmAw2uE2tywr2jE7viwGg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/molly-moons-homemade-ice-cream-seattle-6?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1241, 'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6614912966508, 'longitude': -122.338043573655}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1622 1/2 N 45th St', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98103', 'country': 'US', 'state': 'WA', 'display_address': ['1622 1/2 N 45th St', 'Seattle, WA 98103']}, 'phone': '+12065475105', 'display_phone': '(206) 547-5105', 'distance': 4015.534151237254}
# {'id': 'ANRznMzskndUpHA93KdEbA', 'alias': 'café-presse-seattle-2', 'name': 'Café Presse', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3KLdYYBJeJibK4fSJJKAHw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/caf%C3%A9-presse-seattle-2?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 1150, 'categories': [{'alias': 'french', 'title': 'French'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.0, 'coordinates': {'latitude': 47.6120529174805, 'longitude': -122.317108154297}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1117 12th Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98122', 'country': 'US', 'state': 'WA', 'display_address': ['1117 12th Ave', 'Seattle, WA 98122']}, 'phone': '+12067097674', 'display_phone': '(206) 709-7674', 'distance': 2025.0169941039107}
# {'id': 'bB9mbLCKSvXltK8za8nK0A', 'alias': 'matts-in-the-market-seattle', 'name': "Matt's in the Market", 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6cnJUwXtwire0DKlsrTTTQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/matts-in-the-market-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 998, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 47.60888, 'longitude': -122.34036}, 'transactions': ['delivery'], 'price': '$$$', 'location': {'address1': '94 Pike St', 'address2': 'Ste 32', 'address3': '', 'city': 'Seattle', 'zip_code': '98101', 'country': 'US', 'state': 'WA', 'display_address': ['94 Pike St', 'Ste 32', 'Seattle, WA 98101']}, 'phone': '+12064677909', 'display_phone': '(206) 467-7909', 'distance': 1874.6459036561484}
# {'id': 'z3B84RJM47aCnfZ69ai8cA', 'alias': 'the-capital-grille-seattle', 'name': 'The Capital Grille', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x559sKUPkItRBQ-OU5-tVA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-capital-grille-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 881, 'categories': [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 47.60826, 'longitude': -122.33538}, 'transactions': [], 'price': '$$$', 'location': {'address1': '1301 4th Ave', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98101', 'country': 'US', 'state': 'WA', 'display_address': ['1301 4th Ave', 'Seattle, WA 98101']}, 'phone': '+12063820900', 'display_phone': '(206) 382-0900', 'distance': 1904.6766127481496}
# {'id': 'Y-OgQKqreMaajTUCPbLPKg', 'alias': 'tsukushinbo-seattle', 'name': 'Tsukushinbo', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r6mFftGhUVvZjSu67PwSVg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/tsukushinbo-seattle?adjust_creative=6vdYi1Kgx9XqvIMey-5Gxg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6vdYi1Kgx9XqvIMey-5Gxg', 'review_count': 889, 'categories': [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'seafood', 'title': 'Seafood'}], 'rating': 4.0, 'coordinates': {'latitude': 47.59985, 'longitude': -122.32681}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '515 S Main St', 'address2': '', 'address3': '', 'city': 'Seattle', 'zip_code': '98104', 'country': 'US', 'state': 'WA', 'display_address': ['515 S Main St', 'Seattle, WA 98104']}, 'phone': '+12064674004', 'display_phone': '(206) 467-4004', 'distance': 2916.7718796688164}

# %%
import requests
from bs4 import BeautifulSoup
from matplotlib import pyplot as plt
class CRA:
    def __init__(self):
        self.url = 'https://gisdata.seattle.gov/server/rest/services/COS/CommunityReportingAreas/MapServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'
        self.json = requests.get(self.url).json()
        self.geometry = {f['attributes']['GEN_ALIAS'] : f['geometry']['rings'] for f in self.json['features']}
    def in_poly(p, V):
        return sum(min(V[i][1], V[i+1][1]) <= p[1] < max(V[i][1], V[i+1][1])
                   and (V[i+1][0] - V[i][0]) * (p[1] - V[i][1]) / (V[i+1][1] - V[i][1]) < p[0] - V[i][0] for i in range(len(V) - 1)) % 2
    def poly_plot(V):
        for i in range(len(V) - 1):
            plt.plot([V[i][1], V[i+1][1]], [V[i][0], V[i+1][0]], 'k')
    def print_cra(self, c):
        for ring in self.geometry[c]:
            CRA.poly_plot(ring)
        plt.title(c)
        plt.xlabel('Latitude')
        plt.ylabel('Longitude')
        plt.ticklabel_format(useOffset=False)
        plt.show()
    def to_cra(self, gps):
        for c in self.geometry:
            for ring in self.geometry[c]:
                if CRA.in_poly(gps[::-1], ring):
                    return c
        return 'Not Found'

# %%
c = CRA()
features = ['name', 'price', 'categories', 'coordinates']
df = pd.DataFrame(L)[features]
df = df[df.price.notna()]
df.price = df.price.map(len)
df.categories = df.categories.map(lambda L : [D['alias'] for D in L])
df.coordinates = df.coordinates.map(dict.values).map(list)
df['cra'] = df.coordinates.map(c.to_cra)
df
# Out:
#                                              name  price  \
# 0                              Pike Place Chowder      2
# 1                               Piroshky Piroshky      1
# 2                                   The Pink Door      2
# 3                                           Paseo      2
# 4                       Ellenos Real Greek Yogurt      1
# ..                                            ...    ...
# 995                        Bookstore Bar and Cafe      2
# 996                                 Aluel Cellars      2
# 997                               Mission Cantina      2
# 998  Shawn O'Donnell's American Grill & Irish Pub      2
# 999                             The Twilight Exit      2
#
#                                 categories  \
# 0                          [seafood, soup]
# 1                      [bakeries, russian]
# 2            [italian, wine_bars, seafood]
# 3           [caribbean, cuban, sandwiches]
# 4                               [icecream]
# ..                                     ...
# 995  [bars, newamerican, breakfast_brunch]
# 996           [winetastingroom, wine_bars]
# 997                [bars, mexican, venues]
# 998                    [irish, irish_pubs]
# 999               [divebars, tradamerican]
#
#                              coordinates                       cra
# 0                 [47.60939, -122.34112]  Downtown Commercial Core
# 1                 [47.60991, -122.34231]                  Belltown
# 2                  [47.61028, -122.3425]                  Belltown
# 3                 [47.65849, -122.35031]                   Fremont
# 4                [47.608912, -122.34058]  Downtown Commercial Core
# ..                                   ...                       ...
# 995              [47.605121, -122.33678]  Downtown Commercial Core
# 996  [47.62097744904, -122.321928218007]              Capitol Hill
# 997               [47.58225, -122.38689]              Alki/Admiral
# 998               [47.65169, -122.35031]                   Fremont
# 999                [47.60818, -122.2994]  Central Area/Squire Park
#
# [960 rows x 5 columns]

# %%
import numpy as np
stevenph = np.array(list(df.coordinates))

# %%
seattle_restaurants = df.to_csv('./project_5.csv')
